# %%
import pandas as pd

file_path = "data_scaling_skewed_data.csv"
df = pd.read_csv(file_path)

# %%
import matplotlib.pyplot as plt
from matplotlib.figure import SubFigure
import seaborn as sns
plt.figure(figsize=(9,6))
plt.scatter(df["Study_Hours"],df["Exam_Score"],color="pink")
plt.xlabel("Study_Hours")
plt.ylabel("Exam_Score")
plt.show()

# %%
df.columns
# Out:
# Index(['Student_ID', 'Study_Hours', 'Age', 'Attendance', 'Family_Income',
#        'Internet_Usage_Hours', 'Exam_Score'],
#       dtype='str')

# %%
import numpy as np
def calc_reg(x,y):
  Nr=0
  Dr=0
  n=len(x)
  x_mean= np.mean(x)
  y_mean=np.mean(y)
  for i in range(n):
    Nr+=(x[i]-x_mean)*(y[i]-y_mean)
    Dr+=(x[i]-x_mean)**2
  m=Nr/Dr
  b=y_mean-m*x_mean 
  y_pred = m*x + b
  print(f"slope(m)",m)
  print(f"Y-intersept(b)",b)
  return m,b,y_pred

# %%
x= df["Study_Hours"].values
x
# Out:
# array([ 4.79,  2.99,  2.76,  2.76,  9.3 ,  5.73,  2.26,  4.94,  4.  ,
#         0.43,  1.34,  4.21,  8.73,  2.78,  2.12,  3.63,  2.01,  2.64,
#         3.3 ,  1.28,  5.94,  1.07,  0.95,  3.87,  5.63,  3.8 ,  3.04,
#         2.61,  2.28,  6.88,  4.24,  2.43,  1.87,  5.18,  6.77,  6.36,
#         1.6 ,  2.6 ,  2.24,  2.88,  5.9 ,  8.2 ,  4.36,  1.93,  3.24,
#         9.23,  3.56,  2.62,  2.8 ,  4.34,  1.65,  2.2 ,  6.3 ,  4.26,
#         3.59,  6.51,  1.83,  2.56,  4.16,  4.05,  0.85,  2.36,  2.93,
#         4.49,  4.04,  3.14,  0.43,  3.27,  3.49, 14.6 ,  2.86,  4.17,
#         7.24,  5.68,  8.43,  0.87,  1.37,  2.07,  0.72,  3.51,  1.48,
#         9.15,  1.69,  2.57,  5.91,  1.06,  0.67,  3.83,  4.05,  5.79,
#         4.87,  4.16,  1.87,  3.97,  4.15,  1.81, 10.84,  4.71,  1.4 ,
#         5.81])

# %%
y = df[["Exam_Score"]].values
y
# Out:
# array([68.46, 58.53, 50.72, 72.44, 60.92, 52.93, 62.24, 57.02, 90.25,
#        80.58, 69.9 , 87.76, 70.93, 59.66, 88.28, 76.47, 57.55, 67.72,
#        59.49, 53.41, 81.11, 92.91, 53.22, 76.76, 62.19, 64.15, 62.89,
#        59.63, 70.58, 60.03, 73.25, 69.4 , 67.13, 59.11, 63.08, 79.06,
#        76.01, 58.27, 71.19, 79.02, 49.97, 76.52, 62.05, 76.85, 60.84,
#        48.34, 50.47, 70.58, 73.12, 59.15, 77.66, 50.06, 69.21, 55.47,
#        62.18, 70.57, 59.68, 65.39, 82.08, 63.08, 80.03, 56.44, 76.36,
#        87.3 , 40.34, 60.44, 76.92, 67.56, 74.45, 62.75, 71.04, 68.13,
#        84.01, 73.05, 74.05, 65.06, 64.15, 64.81, 74.73, 64.95, 73.48,
#        94.9 , 80.45, 66.09, 84.41, 65.1 , 45.54, 57.9 , 47.55, 65.78,
#        70.22, 90.12, 73.92, 67.37, 79.95, 43.47, 72.83, 79.25, 52.26,
#        83.73])

# %%
y_pred
# Out:
# array([[67.69255698],
#        [67.84830503],
#        [67.29206198],
#        [67.64527632],
#        [67.46727854],
#        [67.74818128],
#        [68.64929503],
#        [67.24756253],
#        [67.31153049],
#        [68.00961552],
#        [67.26981226],
#        [67.04731503],
#        [67.41443545],
#        [67.14465757],
#        [67.79268073],
#        [68.20151937],
#        [67.34768628],
#        [67.99014701],
#        [68.54917128],
#        [67.09459569]])

# %%
import numpy as np
m,b,y_pred = calc_reg(x,y)
# Out:
# slope(m) 0.3264903120756834
# Y-intersept(b) 66.63089958612869

# %%
import matplotlib.pyplot as plt
from matplotlib.figure import SubFigure
import seaborn as sns
plt.figure(figsize=(9,6))
plt.scatter(df["Study_Hours"],df["Exam_Score"],color="pink")
plt.plot(df["Study_Hours"],y_pred,color="blue")
plt.xlabel("Study_Hours")
plt.ylabel("Exam_Score")
plt.show()

# %%
x= df[["Study_Hours"]].values
y= df["Exam_Score"].values
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_[0]
# Out:
# np.float64(0.2878046294889012)

# %%
model.intercept_
# Out:
# np.float64(66.63006070864115)

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([67.74386462, 67.64025496, 67.50498678, 68.29644951, 67.82444992,
#        67.03298719, 68.30220561, 67.18552364, 67.79566946, 67.73235244,
#        67.8417182 , 67.43015758, 67.79566946, 67.05601156, 67.42440149,
#        67.56254771, 68.50366885, 66.93513362, 67.9223035 , 69.30664376])

# %%
compare = pd.DataFrame({
    "Actual":y_test,
    "Predict":y_pred
})

# %%
compare
# Out:
#     Actual    Predict
# 0    76.76  67.743865
# 1    64.95  67.640255
# 2    62.89  67.504987
# 3    65.78  68.296450
# 4    79.95  67.824450
# 5    52.26  67.032987
# 6    83.73  68.302206
# 7    76.85  67.185524
# 8    47.55  67.795669
# 9    57.90  67.732352
# 10   87.76  67.841718
# 11   59.66  67.430158
# 12   63.08  67.795669
# 13   73.48  67.056012
# 14   72.44  67.424401
# 15   60.84  67.562548
# 16   70.57  68.503669
# 17   65.10  66.935134
# 18   87.30  67.922303
# 19   60.92  69.306644
