# %%
l=[1,2,3,4,5,6,7]
a=map(lambda x:x>5,l)
print(list(a))
# Out:
# [False, False, False, False, False, True, True]

# %%
l=[1,2,3,4,5,6,7]
a=filter(lambda x:x>5,l)
print(list(a))
# Out:
# [6, 7]

# %%
import functools
l=[1,2,3,4,5]
a= functools.reduce(lambda x,y:x+y,l)
print(a)
# Out:
# 15

# %%
def func(n):
    for i in range(n):
         return i

# %%
func(4)
# Out:
# 0

# %%
def func1(n):
    l=[]
    for i in range(n):
        if i%3==0:
            l.append(i)
        return l

# %%
func1(10)
# Out:
# [0]

# %%
def func1(n):
    l=[]
    for i in range(n):
        if i%3==0:
            l.append(i)
    return l
func1(10)
# Out:
# [0, 3, 6, 9]

# %%
def func1(n):
    l=[]
    for i in range(n):
        if i%3==0:
            l.append(i)
    return l
func1(1000)
# Out:
# [0,
#  3,
#  6,
#  9,
#  12,
#  15,
#  18,
#  21,
#  24,
#  27,
#  30,
#  33,
#  36,
#  39,
#  42,
#  45,
#  48,
#  51,
#  54,
#  57,
#  60,
#  63,
#  66,
#  69,
#  72,
#  75,
#  78,
#  81,
#  84,
#  87,
#  90,
#  93,
#  96,
#  99,
#  102,
#  105,
#  108,
#  111,
#  114,
#  117,
#  120,
#  123,
#  126,
#  129,
#  132,
#  135,
#  138,
#  141,
#  144,
#  147,
#  150,
#  153,
#  156,
#  159,
#  162,
#  165,
#  168,
#  171,
#  174,
#  177,
#  180,
#  183,
#  186,
#  189,
#  192,
#  195,
#  198,
#  201,
#  204,
#  207,
#  210,
#  213,
#  216,
#  219,
#  222,
#  225,
#  228,
#  231,
#  234,
#  237,
#  240,
#  243,
#  246,
#  249,
#  252,
#  255,
#  258,
#  261,
#  264,
#  267,
#  270,
#  273,
#  276,
#  279,
#  282,
#  285,
#  288,
#  291,
#  294,
#  297,
#  300,
#  303,
#  306,
#  309,
#  312,
#  315,
#  318,
#  321,
#  324,
#  327,
#  330,
#  333,
#  336,
#  339,
#  342,
#  345,
#  348,
#  351,
#  354,
#  357,
#  360,
#  363,
#  366,
#  369,
#  372,
#  375,
#  378,
#  381,
#  384,
#  387,
#  390,
#  393,
#  396,
#  399,
#  402,
#  405,
#  408,
#  411,
#  414,
#  417,
#  420,
#  423,
#  426,
#  429,
#  432,
#  435,
#  438,
#  441,
#  444,
#  447,
#  450,
#  453,
#  456,
#  459,
#  462,
#  465,
#  468,
#  471,
#  474,
#  477,
#  480,
#  483,
#  486,
#  489,
#  492,
#  495,
#  498,
#  501,
#  504,
#  507,
#  510,
#  513,
#  516,
#  519,
#  522,
#  525,
#  528,
#  531,
#  534,
#  537,
#  540,
#  543,
#  546,
#  549,
#  552,
#  555,
#  558,
#  561,
#  564,
#  567,
#  570,
#  573,
#  576,
#  579,
#  582,
#  585,
#  588,
#  591,
#  594,
#  597,
#  600,
#  603,
#  606,
#  609,
#  612,
#  615,
#  618,
#  621,
#  624,
#  627,
#  630,
#  633,
#  636,
#  639,
#  642,
#  645,
#  648,
#  651,
#  654,
#  657,
#  660,
#  663,
#  666,
#  669,
#  672,
#  675,
#  678,
#  681,
#  684,
#  687,
#  690,
#  693,
#  696,
#  699,
#  702,
#  705,
#  708,
#  711,
#  714,
#  717,
#  720,
#  723,
#  726,
#  729,
#  732,
#  735,
#  738,
#  741,
#  744,
#  747,
#  750,
#  753,
#  756,
#  759,
#  762,
#  765,
#  768,
#  771,
#  774,
#  777,
#  780,
#  783,
#  786,
#  789,
#  792,
#  795,
#  798,
#  801,
#  804,
#  807,
#  810,
#  813,
#  816,
#  819,
#  822,
#  825,
#  828,
#  831,
#  834,
#  837,
#  840,
#  843,
#  846,
#  849,
#  852,
#  855,
#  858,
#  861,
#  864,
#  867,
#  870,
#  873,
#  876,
#  879,
#  882,
#  885,
#  888,
#  891,
#  894,
#  897,
#  900,
#  903,
#  906,
#  909,
#  912,
#  915,
#  918,
#  921,
#  924,
#  927,
#  930,
#  933,
#  936,
#  939,
#  942,
#  945,
#  948,
#  951,
#  954,
#  957,
#  960,
#  963,
#  966,
#  969,
#  972,
#  975,
#  978,
#  981,
#  984,
#  987,
#  990,
#  993,
#  996,
#  999]

# %%
import sys
print(sys.getsizeof(func1(10000)))
# Out:
# 29336

# %%
def func1(n):
    l=[]
    for i in range(n):
        if i%3==0:
            l.append(i)
    yield l
func1(10000000000)
# Out:
# <generator object func1 at 0x00000257425EDE00>

# %%
def func2(n):
    for i in range(n):
        if i%3==0:
           yield i
           print("hi")

# %%
a = func2(1000000000)
1
# Out:
# 1

# %%
print(next(a))
# Out:
# 0

# %%
print(next(a))
print(sys.getsizeof(a))
# Out:
# hi
# 9
# 216

# %%
l=[1,2,3,4]
print(l[6])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[34], line 2
#       1 l=[1,2,3,4]
# ----> 2 print(l[6])
#
# IndexError: list index out of range

# %%
d={
    "a"=1
    "b"=2
}
print(d['c'])
# Out:
#   Cell In[35], line 2
#     "a"=1
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
a=5
print(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 2
#       1 a=5
# ----> 2 print(b)
#
# NameError: name 'b' is not defined

# %%
a=int(input("Guess the number: "))
print(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 a=int(input("Guess the number: "))
#       2 print(a)
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
a=3
b='a'
result= a+b
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 3
#       1 a=3
#       2 b='a'
# ----> 3 result= a+b
#       4 print(result)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
try:
    l=[1,2,3,4]
    print(l[0])
except Exception as e:
    print(type(e).__name__)
    print(e)
finally:
    print("finally executed")
# Out:
# 1
# finally executed

# %%
try:
    l=[1,2,3,4]
    print(l[6])
except Exception as e:
    print(type(e).__name__)
    print(e)
finally:
    print("finally executed")
# Out:
# IndexError
# list index out of range
# finally executed

# %%
try:
    d={
    "a"=1,
    "b"=2,
}
print(d['c'])
except Exception as e:
    print(type(e).__name__)
    print(e)
finally:
    print("finally executed")
# Out:
#   Cell In[46], line 3
#     "a"=1,
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
try:
  a=5
print(b)
except NameError as e:
    print("put upt")
finally:
    print("finally executed")a=5
print(b)
