# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = "/content/drive/MyDrive/2026 AI class/dataset/penguins_size.csv"

# %%
import pandas as pd
df = pd.read_csv(file_path)

# %%
df.head(10)
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
# 5  Adelie  Torgersen              39.3             20.6              190.0
# 6  Adelie  Torgersen              38.9             17.8              181.0
# 7  Adelie  Torgersen              39.2             19.6              195.0
# 8  Adelie  Torgersen              34.1             18.1              193.0
# 9  Adelie  Torgersen              42.0             20.2              190.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE
# 5       3650.0    MALE
# 6       3625.0  FEMALE
# 7       4675.0    MALE
# 8       3475.0     NaN
# 9       4250.0     NaN

# %%
df.tail(10)
# Out:
#     species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 334  Gentoo  Biscoe              46.2             14.1              217.0
# 335  Gentoo  Biscoe              55.1             16.0              230.0
# 336  Gentoo  Biscoe              44.5             15.7              217.0
# 337  Gentoo  Biscoe              48.8             16.2              222.0
# 338  Gentoo  Biscoe              47.2             13.7              214.0
# 339  Gentoo  Biscoe               NaN              NaN                NaN
# 340  Gentoo  Biscoe              46.8             14.3              215.0
# 341  Gentoo  Biscoe              50.4             15.7              222.0
# 342  Gentoo  Biscoe              45.2             14.8              212.0
# 343  Gentoo  Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# 334       4375.0  FEMALE
# 335       5850.0    MALE
# 336       4875.0       .
# 337       6000.0    MALE
# 338       4925.0  FEMALE
# 339          NaN     NaN
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE

# %%
df.shape
# Out:
# (344, 7)

# %%
# viewing columns name
df.columns
# Out:
# Index(['species', 'island', 'culmen_length_mm', 'culmen_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %%
df.describe(include= "object")
# Out:
#        species  island   sex
# count      344     344   334
# unique       3       3     3
# top     Adelie  Biscoe  MALE
# freq       152     168   168

# %%
df["species"].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
df["island"].unique()
df["island"].value_counts()
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %%
df["sex"].unique()
df["sex"].value_counts()
# Out:
# sex
# MALE      168
# FEMALE    165
# .           1
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
# loc = localizer and iloc = index localizer
df.loc[2,"sex"]
# Out:
# 'FEMALE'

# %%
df["culmen_length_mm"].mean()
# Out:
# np.float64(43.9219298245614)

# %%
# handling missing values
df["culmen_length_mm"] = df["culmen_length_mm"].fillna(df["culmen_length_mm"].mean())

df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen          39.10000             18.7              181.0
# 1    Adelie  Torgersen          39.50000             17.4              186.0
# 2    Adelie  Torgersen          40.30000             18.0              195.0
# 3    Adelie  Torgersen          43.92193              NaN                NaN
# 4    Adelie  Torgersen          36.70000             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe          43.92193              NaN                NaN
# 340  Gentoo     Biscoe          46.80000             14.3              215.0
# 341  Gentoo     Biscoe          50.40000             15.7              222.0
# 342  Gentoo     Biscoe          45.20000             14.8              212.0
# 343  Gentoo     Biscoe          49.90000             16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# 2         3250.0  FEMALE
# 3            NaN     NaN
# 4         3450.0  FEMALE
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE
#
# [344 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['species', 'island', 'culmen_length_mm', 'culmen_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
col = ["culmen_depth_mm","flipper_length_mm", "body_mass_g"]
df[col] = df[col].fillna(df[col].mean())

# %%
df.isna().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      0
# culmen_depth_mm       0
# flipper_length_mm     0
# body_mass_g           0
# sex                  10
# dtype: int64

# %%
mass_median = df.groupby(['species','sex'])["body_mass_g"].median()
mass_median["Adelie"]["FEMALE"]
# Out:
# np.float64(3400.0)

# %%
mass_median
# Out:
# species    sex
# Adelie     FEMALE    3400.0
#            MALE      4000.0
# Chinstrap  FEMALE    3550.0
#            MALE      3950.0
# Gentoo     .         4875.0
#            FEMALE    4700.0
#            MALE      5500.0
# Name: body_mass_g, dtype: float64

# %%
df["species"]
# Out:
# 0      Adelie
# 1      Adelie
# 2      Adelie
# 3      Adelie
# 4      Adelie
#         ...
# 339    Gentoo
# 340    Gentoo
# 341    Gentoo
# 342    Gentoo
# 343    Gentoo
# Name: species, Length: 344, dtype: object

# %%
def fill_empty(row):
  spec = row["species"]
  try:
    male_mass_med = mass_median[spec]["MALE"]
    female_mass_med = mass_median[spec]["FEMALE"]
  except:
    return "MALE"

  threshold = (male_mass_med + female_mass_med) / 2
  if  row["body_mass_g"] >= threshold:
    return "MALE"
  else:
    return "FEMALE"

# %%
mask_gender = (df["sex"].isna()) | (df["sex"] == ".")
mask_gender.sum()
# Out:
# np.int64(11)

# %%
df.loc[mask_gender,"sex"] = df[mask_gender].apply(fill_empty,axis = 1)

# %%
df.isna().sum()
# Out:
# species              0
# island               0
# culmen_length_mm     0
# culmen_depth_mm      0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %%
import seaborn as sns
sns.displot(df["flipper_length_mm"],kde = True)

# %%
a = df["species"].value_counts()
a
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['species', 'island', 'culmen_length_mm', 'culmen_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
# Correlation
numerical_col = ['culmen_length_mm', 'culmen_depth_mm','flipper_length_mm', 'body_mass_g']
corr_matrix = df[numerical_col].corr()
corr_matrix
# Out:
#                    culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# culmen_length_mm           1.000000        -0.235053           0.656181
# culmen_depth_mm           -0.235053         1.000000          -0.583851
# flipper_length_mm          0.656181        -0.583851           1.000000
# body_mass_g                0.595110        -0.471916           0.871202
#
#                    body_mass_g
# culmen_length_mm      0.595110
# culmen_depth_mm      -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %%
sns.heatmap(corr_matrix,annot = True)
# Out:
# <Axes: >

# %%
df["culmen_ratio"] = df["culmen_length_mm"] / df["culmen_depth_mm"]

# %%
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen          39.10000         18.70000         181.000000
# 1  Adelie  Torgersen          39.50000         17.40000         186.000000
# 2  Adelie  Torgersen          40.30000         18.00000         195.000000
# 3  Adelie  Torgersen          43.92193         17.15117         200.915205
# 4  Adelie  Torgersen          36.70000         19.30000         193.000000
#
#    body_mass_g     sex  culmen_ratio
# 0  3750.000000    MALE      2.090909
# 1  3800.000000  FEMALE      2.270115
# 2  3250.000000  FEMALE      2.238889
# 3  4201.754386    MALE      2.560871
# 4  3450.000000  FEMALE      1.901554

# %%
# Correlation
numerical_col = ['culmen_length_mm', 'culmen_depth_mm','flipper_length_mm', 'body_mass_g','culmen_ratio']
corr_matrix = df[numerical_col].corr()
sns.heatmap(corr_matrix,annot=  True)
# Out:
# <Axes: >

# %%
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen          39.10000         18.70000         181.000000
# 1  Adelie  Torgersen          39.50000         17.40000         186.000000
# 2  Adelie  Torgersen          40.30000         18.00000         195.000000
# 3  Adelie  Torgersen          43.92193         17.15117         200.915205
# 4  Adelie  Torgersen          36.70000         19.30000         193.000000
#
#    body_mass_g     sex  culmen_ratio
# 0  3750.000000    MALE      2.090909
# 1  3800.000000  FEMALE      2.270115
# 2  3250.000000  FEMALE      2.238889
# 3  4201.754386    MALE      2.560871
# 4  3450.000000  FEMALE      1.901554

# %%
# mapping

gender_map = {
    "MALE":0,
    "FEMALE":1
}
df["encoded_sex"]= df["sex"].map(gender_map)
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen          39.10000         18.70000         181.000000
# 1  Adelie  Torgersen          39.50000         17.40000         186.000000
# 2  Adelie  Torgersen          40.30000         18.00000         195.000000
# 3  Adelie  Torgersen          43.92193         17.15117         200.915205
# 4  Adelie  Torgersen          36.70000         19.30000         193.000000
#
#    body_mass_g     sex  culmen_ratio  encoded_sex
# 0  3750.000000    MALE      2.090909            0
# 1  3800.000000  FEMALE      2.270115            1
# 2  3250.000000  FEMALE      2.238889            1
# 3  4201.754386    MALE      2.560871            0
# 4  3450.000000  FEMALE      1.901554            1

# %%
import pandas as pd
df = pd.get_dummies(df,columns = ["island"],dtype = int)
df
# Out:
#     species  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie          39.10000         18.70000         181.000000
# 1    Adelie          39.50000         17.40000         186.000000
# 2    Adelie          40.30000         18.00000         195.000000
# 3    Adelie          43.92193         17.15117         200.915205
# 4    Adelie          36.70000         19.30000         193.000000
# ..      ...               ...              ...                ...
# 339  Gentoo          43.92193         17.15117         200.915205
# 340  Gentoo          46.80000         14.30000         215.000000
# 341  Gentoo          50.40000         15.70000         222.000000
# 342  Gentoo          45.20000         14.80000         212.000000
# 343  Gentoo          49.90000         16.10000         213.000000
#
#      body_mass_g     sex  culmen_ratio  encoded_sex  island_Biscoe  \
# 0    3750.000000    MALE      2.090909            0              0
# 1    3800.000000  FEMALE      2.270115            1              0
# 2    3250.000000  FEMALE      2.238889            1              0
# 3    4201.754386    MALE      2.560871            0              0
# 4    3450.000000  FEMALE      1.901554            1              0
# ..           ...     ...           ...          ...            ...
# 339  4201.754386  FEMALE      2.560871            1              1
# 340  4850.000000  FEMALE      3.272727            1              1
# 341  5750.000000    MALE      3.210191            0              1
# 342  5200.000000  FEMALE      3.054054            1              1
# 343  5400.000000    MALE      3.099379            0              1
#
#      island_Dream  island_Torgersen
# 0               0                 1
# 1               0                 1
# 2               0                 1
# 3               0                 1
# 4               0                 1
# ..            ...               ...
# 339             0                 0
# 340             0                 0
# 341             0                 0
# 342             0                 0
# 343             0                 0
#
# [344 rows x 11 columns]

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder(sparse_output=False,dtype = int)
encoded = encoder.fit_transform(df[["species"]])
df[encoder.get_feature_names_out()] = encoded
df.head()
# Out:
#   species  culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0  Adelie          39.10000         18.70000         181.000000  3750.000000
# 1  Adelie          39.50000         17.40000         186.000000  3800.000000
# 2  Adelie          40.30000         18.00000         195.000000  3250.000000
# 3  Adelie          43.92193         17.15117         200.915205  4201.754386
# 4  Adelie          36.70000         19.30000         193.000000  3450.000000
#
#       sex  culmen_ratio  encoded_sex  island_Biscoe  island_Dream  \
# 0    MALE      2.090909            0              0             0
# 1  FEMALE      2.270115            1              0             0
# 2  FEMALE      2.238889            1              0             0
# 3    MALE      2.560871            0              0             0
# 4  FEMALE      1.901554            1              0             0
#
#    island_Torgersen  species_Adelie  species_Chinstrap  species_Gentoo
# 0                 1               1                  0               0
# 1                 1               1                  0               0
# 2                 1               1                  0               0
# 3                 1               1                  0               0
# 4                 1               1                  0               0

# %%
df.drop(columns = ["sex","species"],inplace=  True)
df
# Out:
#      culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0            39.10000         18.70000         181.000000  3750.000000
# 1            39.50000         17.40000         186.000000  3800.000000
# 2            40.30000         18.00000         195.000000  3250.000000
# 3            43.92193         17.15117         200.915205  4201.754386
# 4            36.70000         19.30000         193.000000  3450.000000
# ..                ...              ...                ...          ...
# 339          43.92193         17.15117         200.915205  4201.754386
# 340          46.80000         14.30000         215.000000  4850.000000
# 341          50.40000         15.70000         222.000000  5750.000000
# 342          45.20000         14.80000         212.000000  5200.000000
# 343          49.90000         16.10000         213.000000  5400.000000
#
#      culmen_ratio  encoded_sex  island_Biscoe  island_Dream  island_Torgersen  \
# 0        2.090909            0              0             0                 1
# 1        2.270115            1              0             0                 1
# 2        2.238889            1              0             0                 1
# 3        2.560871            0              0             0                 1
# 4        1.901554            1              0             0                 1
# ..            ...          ...            ...           ...               ...
# 339      2.560871            1              1             0                 0
# 340      3.272727            1              1             0                 0
# 341      3.210191            0              1             0                 0
# 342      3.054054            1              1             0                 0
# 343      3.099379            0              1             0                 0
#
#      species_Adelie  species_Chinstrap  species_Gentoo
# 0                 1                  0               0
# 1                 1                  0               0
# 2                 1                  0               0
# 3                 1                  0               0
# 4                 1                  0               0
# ..              ...                ...             ...
# 339               0                  0               1
# 340               0                  0               1
# 341               0                  0               1
# 342               0                  0               1
# 343               0                  0               1
#
# [344 rows x 12 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df["culmen_length_mm"] = scaler.fit_transform(df[['culmen_length_mm']])

# %%
df.head()
# Out:
#    culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0          0.254545         18.70000         181.000000  3750.000000
# 1          0.269091         17.40000         186.000000  3800.000000
# 2          0.298182         18.00000         195.000000  3250.000000
# 3          0.429888         17.15117         200.915205  4201.754386
# 4          0.167273         19.30000         193.000000  3450.000000
#
#    culmen_ratio  encoded_sex  island_Biscoe  island_Dream  island_Torgersen  \
# 0      2.090909            0              0             0                 1
# 1      2.270115            1              0             0                 1
# 2      2.238889            1              0             0                 1
# 3      2.560871            0              0             0                 1
# 4      1.901554            1              0             0                 1
#
#    species_Adelie  species_Chinstrap  species_Gentoo
# 0               1                  0               0
# 1               1                  0               0
# 2               1                  0               0
# 3               1                  0               0
# 4               1                  0               0
